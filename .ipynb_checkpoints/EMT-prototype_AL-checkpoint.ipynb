# %% [markdown]
# ## proof of concept for EMT decision-support

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class Patient:
    def __init__(self,location,health):
        self.health = health
        self.location = location
        self.status = 0

class ICU:
    def __init__(self,name,metadata): # passed ICU metadata
        self.name = name
        self.max_beds = metadata['max_beds']
        self.max_ventilators = metadata['max_ventilators']
        self.used_beds = 0
        self.used_ventilators = 0
    
    def updateUsed(self,delta_beds=1, delta_ventilators=0):
        self.used_beds += delta_beds
        self.used_ventilators += delta_ventilators
    
class ED:
    def __init__(self,name,metadata): # passed ER metadata
        self.name = name
        self.max_beds = metadata['max_beds']
        self.used_beds = 0
    
    def updateUsed(self,delta_beds=1):
        self.used_beds += delta_beds
        
class Hospital:
    def __init__(self,name,metadata): # passed hospital metadata
        self.name = name 
        self.location = metadata['location']
        self.ICU = ICU(name=self.name, metadata=metadata['ICU'])
        self.ED = ED(name=self.name, metadata=metadata['ED'])
        self.patients = []
        
    def distanceToPatient(self,location):
        return np.linalg.norm(self.location-location)
    
    def updateUsedED(self,delta_beds=1):
        self.ED.updateUsed(delta_beds=delta_beds)
        
    def updateUsedICU(self,delta_beds=1, delta_ventilators=1):
        self.ICU.updateUsed(delta_beds=delta_beds,delta_ventilators=delta_ventilators)
        
    def availableBedED(self):
        return self.ED.max_beds-self.ED.used_beds
    
    def availableBedICU(self):
        return self.ICU.max_beds-self.ICU.used_beds
    
    def availableVentilatorICU(self):
        return self.ICU.max_ventilators-self.ICU.used_ventilators
    
    def admitToED(self, delta_beds=1, patient=None):
        self.ED.updateUsed(delta_beds=delta_beds)
        if (patient != None):
            self.patients.append(patient)
            
    def admitToICU(self, delta_beds=1, patient=None):
        self.ED.updateUsed(delta_beds=-delta_beds)
        self.ICU.updateUsed(delta_beds=delta_beds)
        
    def dischargefromED(self, delta_beds=1, patient=None):
        self.ED.updateUsed(delta_beds=-delta_beds)
        if (patient != None):
            self.patients.remove(patient)
            
    def dischargefromICU(self, delta_beds=1, patient=None):
        self.ICU.updateUsed(delta_beds=-delta_beds)
        if (patient != None):
            self.patients.remove(patient)
    
class City:
    def __init__(self, metadata): # all metadata
        self.hospitals = []
        for name, data in metadata.items():
            self.hospitals.append(Hospital(name=name, metadata=data))
    
    # naive implementation — distance based priority queue 
    def new_patient_naive(self, patient):
        distances = []
        for hospital in self.hospitals:
            distances += [hospital.distanceToPatient(patient.location)]
        found = False
        ind = 0
        while found == False and ind < len(self.hospitals): 
            selected_hospital = self.hospitals[np.argsort(distances)[ind]]
            if selected_hospital.availableBedED() > 0:
                found = True
                selected_hospital.admitToED(patient=patient)
            ind += 1
        if found == False:
            #print('city EDs oversaturated')
            return None
        return selected_hospital
    
    # communication implementation — 
    def new_patient(self, patient):
        metric = []
        for hospital in self.hospitals:
            metric += [1.0/(hospital.availableBedED()+1)] # could be whatever metric
        found = False
        ind = 0
        while found == False and ind < len(self.hospitals): 
            selected_hospital = self.hospitals[np.argsort(metric)[ind]]
            if selected_hospital.availableBedED() > 0:
                found = True
                selected_hospital.admitToED(patient=patient)
            ind += 1
        if found == False:
            #print('city EDs oversaturated')
            return None
        return selected_hospital

# %%
def createPatient():
    location = np.asarray([np.random.random(),np.random.random()])
    health = np.random.random()
    patient = Patient(location=location,health=health)
    return patient

# %%
def simulate(city, nT, nP, health_tol_1, health_tol_2, city2=None, model=None):
    
    edwt = np.zeros((nH,nP))
    dwt = np.zeros(nP)
    edwt2 = np.zeros((nH,nP))
    dwt2 = np.zeros(nP)
    
    for trial in range(nT):
        for i in range(nP):
            patient = createPatient()
            if city2 is None:
                if model == 'naive':
                    hos = city.new_patient_naive(patient)
                else:
                    hos = city.new_patient(patient)
                if hos is None:
                    break
                
                # admit patients in worst health conditions to ICU
                if patient.health <= health_tol_1:
                    hos.admitToICU()
                # discharge patients who are fine 
                elif patient.health >= health_tol_2:
                    hos.dischargefromED()
                    
                # update probabilistic department admits/disharges
                for j in range(len(city.hospitals)):
                    numDischargedED = np.random.exponential(1)
                    numAdmitICU = np.random.exponential(1)
                    numDishargedICU = np.random.exponential(1)
                    
                    if (np.random.random() < 0.05 and numDischargedED < city.hospitals[j].ED.used_beds):
                        city.hospitals[j].dischargefromED(numDischargedED)
                    
                    # update stats
                    edwt[j,i] += city.hospitals[j].availableBedED()/nT
                
                dwt[i] += hos.distanceToPatient(patient.location)/nT
            
            else:
                hos = city.new_patient(patient)
                if hos is None:
                    break
                else:
                    # admit patients in worst health conditions to ICU
                    if patient.health <= health_tol_1:
                        hos.admitToICU()
                    # discharge patients who are fine 
                    if patient.health >= health_tol_2:
                        hos.dischargefromED()
                   
                    # update probabilistic department admits/disharges
                    for j in range(len(city.hospitals)):
                        numDischargedED = np.random.exponential(1)
                        numAdmitICU = np.random.exponential(1)
                        numDishargedICU = np.random.exponential(1)
                        
                        if (np.random.random()<0.05 and numDischargedED<city.hospitals[j].ED.used_beds):
                            city.hospitals[j].dischargefromED(numDischargedED)
                        
                        # update stats
                        edwt[j,i] += city.hospitals[j].availableBedED()/nT
                        
                    dwt[i] += hos.distanceToPatient(patient.location)/nT
               
                hos = city2.new_patient_naive(patient)
                
                if hos is None:
                    break
                else:
                    # admit patients in worst health conditions to ICU
                    if patient.health <= health_tol_1:
                        hos.admitToICU()
                    # discharge patients who are fine 
                    if patient.health >= health_tol_2:
                        hos.dischargefromED()
                    
                    # update probabilistic department admits/disharges
                    for j in range(len(city2.hospitals)):
                        numDischargedED = np.random.exponential(1)
                        numAdmitICU = np.random.exponential(1)
                        numDishargedICU = np.random.exponential(1)
                        
                        if (np.random.random()<0.05 and numDischargedED<city2.hospitals[j].ED.used_beds):
                            city2.hospitals[j].dischargefromED(numDischargedED)
                        
                        # update stats
                        edwt2[j,i] += city2.hospitals[j].availableBedED()/nT
                    
                    dwt2[i] += hos.distanceToPatient(patient.location)/nT
    
    if (city2 == None):
        return edwt,dwt
    else:
        return edwt,dwt,edwt2,dwt2

# %%
fig = plt.figure(figsize=(14,14))

nP = 10000
nH = 16
nT = 500
health_tol_1 = .05
health_tol_2 = .95

metadata = {}
# create hospitals
for i in range(int(np.sqrt(nH))):
    for j in range(int(np.sqrt(nH))):
        name = 'h'+str(i)+str(j)
        metadata[name] = {'location': (np.linspace(0,1,int(nH/2))[i],np.linspace(0,1,int(nH/2))[j]), 
                          'ED': {'max_beds': np.random.randint(30,100)}, 
                          'ICU': {'max_beds': np.random.randint(20,75), 
                          'max_ventilators': np.random.randint(10,40)} }

city1 = City(metadata=metadata)
city2 = City(metadata=metadata)

for idx, (name, data) in enumerate(metadata.items()): 
    print('ED {} has '.format(idx) + str(data['ED']['max_beds']) + ' beds')
    print('ICU {} has '.format(idx) + str(data['ICU']['max_beds']) + ' beds, ' + str(data['ICU']['max_ventilators']) + ' ventilators')
    
edwt, dwt, edwtN, dwtN = simulate(city1, nT, nP, health_tol_1, health_tol_2, city2=city2)

print('average fail, communication model: ' + str(np.where(dwt==0)[0][0]))
print('average fail, distance model: ' + str(np.where(dwtN==0)[0][0]))

print('total patient care, communication model: ' + str(np.round(np.sum(edwt))))
print('total patient care, distance model: ' + str(np.round(np.sum(edwtN))))

ax = fig.add_subplot(221)
for i in range(nH):
    ax.plot(edwt[i],label='hospital '+str(i+1))

ax.legend()
ax.set_ylabel('avaible ED beds')
ax.set_xlabel('cumulative new patients')
ax.set_title('communication model')
ax.set_ylim([np.min([edwt,edwtN]),0.2])#np.max([edwt,edwtN])])

ax = fig.add_subplot(222)
for i in range(nH):
    ax.plot(edwtN[i],label='hospital '+str(i+1))

ax.legend()
ax.set_ylabel('available ED beds')
ax.set_xlabel('cumulative new patients')
ax.set_title('distance model')
#ax.set_ylim([np.min([edwt,edwtN]),1])#np.max([edwt,edwtN])])

ax = fig.add_subplot(223)
ax.plot(dwt)
end = np.where(dwt==0)[0][0]
ax.plot(np.cumsum(dwt[0:end])/np.linspace(1,end,end))
ax.set_ylabel('distance travelled by patient')
ax.set_xlabel('cumulative new patient cases')
#ax.set_ylim([np.min([dwt,dwtN]),np.max([dwt,dwtN])])

ax = fig.add_subplot(224)
ax.plot(dwtN)
end = np.where(dwtN==0)[0][0]
ax.plot(np.cumsum(dwtN[0:end])/np.linspace(1,end,end))
ax.set_ylabel('distance travelled by patient')
ax.set_xlabel('cumulative new patient cases')
#ax.set_ylim([np.min([dwt,dwtN]),np.max([dwt,dwtN])])
# Out:
# ED 0 has 51 beds
# ICU 0 has 53 beds, 35 ventilators
# ED 1 has 55 beds
# ICU 1 has 62 beds, 16 ventilators
# ED 2 has 46 beds
# ICU 2 has 28 beds, 12 ventilators
# ED 3 has 95 beds
# ICU 3 has 65 beds, 32 ventilators
# ED 4 has 79 beds
# ICU 4 has 69 beds, 17 ventilators
# ED 5 has 43 beds
# ICU 5 has 61 beds, 15 ventilators
# ED 6 has 76 beds
# ICU 6 has 34 beds, 10 ventilators
# ED 7 has 98 beds
# ICU 7 has 66 beds, 26 ventilators
# ED 8 has 69 beds
# ICU 8 has 35 beds, 16 ventilators
# ED 9 has 60 beds
# ICU 9 has 27 beds, 20 ventilators
# ED 10 has 48 beds
# ICU 10 has 30 beds, 14 ventilators
# ED 11 has 93 beds
# ICU 11 has 58 beds, 13 ventilators
# ED 12 has 72 beds
# ICU 12 has 37 beds, 20 ventilators
# ED 13 has 61 beds
# ICU 13 has 20 beds, 19 ventilators
# ED 14 has 57 beds
# ICU 14 has 50 beds, 23 ventilators
# ED 15 has 58 beds
# ICU 15 has 54 beds, 13 ventilators
# average fail, communication model: 3997
# average fail, distance model: 3996
# total patient care, communication model: 5117.0
# total patient care, distance model: 2969.0
# Text(0.5, 0, 'cumulative new patient cases')

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# Total population, N.
N = 10000
# Initial number of infected, exposed, recovered individuals, I0 and R0.
I0, E0, R0 = 500, 0, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - E0 - R0
# Hospital values 0
HI_ED0, HI_Adm0, HI_ICU0, = 0, 0, 0
#Death value 0 
D0 = 0

# Contact rate, beta, and mean recovery rate, gamma, (in 1/hours).
beta, sigma = 0.1, 1./(5*24)
gamma1, gamma2, gamma3 =  1./(15*24), 1./(12*24), 1./(5*24)
rho = .00001
alpha1 = 1./48
alpha2 = 1./48
chi = alpha2/20
zeta = gamma2

# A grid of time points (in days)
t = np.linspace(0, 24*1000, 24*1000)

# The SEIR model differential equations.
def deriv(y, t, N, beta, sigma, gamma1, gamma2, gamma3, rho, alpha1, alpha2, chi, zeta):
    S, E, I, R, HI_ED, HI_Adm, HI_ICU = y
    dSdt = -beta * S * I / N
    dEdt = beta * S * I / N - sigma * E
    dIdt = sigma * E - rho*I - gamma1*I
    dHI_EDdt = rho*I - alpha2*HI_ED - alpha1*HI_ED
    dHI_Admdt = alpha1*HI_ED - chi*HI_Adm - gamma3*HI_Adm
    dHI_ICUdt = alpha2*HI_ED - (zeta + gamma2)*HI_ICU 
    dRdt = gamma1*I + gamma2*HI_ICU + gamma3*HI_Adm

    return dSdt, dEdt, dIdt, dHI_EDdt, dHI_Admdt, dHI_ICUdt, dRdt

# Initial conditions vector
y0 = S0, E0, I0, HI_ED0, HI_Adm0, HI_ICU0, R0

# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, sigma, gamma1, gamma2, gamma3, rho, alpha1, alpha2, chi, zeta))
S, E, I, HI_ED, HI_Adm, HI_ICU, R = ret.T

# %%
ret.shape
ret.T[:,-1]
# Out:
# array([ 2.51126842e-012,  7.44623180e-040,  1.64432809e-025,
#        -3.48875660e+111,  8.72189150e+110,  9.69099056e+110,
#         1.16291887e+111])

# %%
t_upper = 24*5

plt.plot(S[:t_upper], label='S')
plt.plot(E[:t_upper], label='E')
plt.plot(I[:t_upper], label='I')
plt.plot(HI_ED[:t_upper], label='HI_ED')
plt.plot(HI_Adm[:t_upper], label='HI_Adm')
plt.plot(HI_ICU[:t_upper], label='HI_ICU')
plt.plot(R[:t_upper], label='R')

plt.legend()
plt.xlabel('time (hrs)')
plt.ylabel('Number of individuals')
# Out:
# Text(0, 0.5, 'Number of individuals')

# %%
plt.plot(ret.T[-24*10::,])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-4adc33ac5cea> in <module>()
# ----> 1 plt.plot(ret.T[-24*10::,])
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1948         if data_path.vertices.size > 0:
#    1949             updatex, updatey = line_trans.contains_branch_seperately(
# -> 1950                 self.transData)
#    1951             self.dataLim.update_from_path(data_path,
#    1952                                           self.ignore_existing_data_limits,
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch_seperately(self, other_transform)
#    1352         # for a non-blended transform each separate dimension is the same, so
#    1353         # just return the appropriate shape.
# -> 1354         return [self.contains_branch(other_transform)] * 2
#    1355
#    1356     def __sub__(self, other):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in contains_branch(self, other)
#    1332         # check that a subtree is equal to other (starting from self)
#    1333         for _, sub_tree in self._iter_break_from_left_to_right():
# -> 1334             if sub_tree == other:
#    1335                 return True
#    1336         return False
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2400     def __eq__(self, other):
#    2401         if isinstance(other, (CompositeGenericTransform, CompositeAffine2D)):
# -> 2402             return self is other or (self._a == other._a
#    2403                                      and self._b == other._b)
#    2404         else:
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1654
#    1655     def __eq__(self, other):
# -> 1656         return self._child.__eq__(other)
#    1657
#    1658     def __str__(self):
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    2294         if isinstance(other, (BlendedAffine2D, BlendedGenericTransform)):
#    2295             return (self._x == other._x) and (self._y == other._y)
# -> 2296         elif self._x == self._y:
#    2297             return self._x == other
#    2298         else:
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/matplotlib/transforms.py in __eq__(self, other)
#    1741     def __eq__(self, other):
#    1742         if getattr(other, "is_affine", False):
# -> 1743             return np.all(self.get_matrix() == other.get_matrix())
#    1744         return NotImplemented
#    1745
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2087
#    2088     """
# -> 2089     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2090
#    2091
#
# ~/miniconda2/envs/py36/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      63
#      64 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 65     passkwargs = {}
#      66     for k, v in kwargs.items():
#      67         if v is not np._NoValue:
#
# KeyboardInterrupt:

# %%
# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, axisbelow=True)
ax.plot(t, S/N, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/N, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/N, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)

ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
